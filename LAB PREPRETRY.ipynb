# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
data={ 
    'Name':['pavan','kartkik','vinay','anil'], 
    'reg no':[2,4,6,8], 
    'study_our':[4,5,1,6], 
    'score':[30,40,50,20], 
} 
df=pd.DataFrame(data)
df
# Out:
#       Name  reg no  study_our  score
# 0    pavan       2          4     30
# 1  kartkik       4          5     40
# 2    vinay       6          1     50
# 3     anil       8          6     20

# %% [markdown]
# # using map function

# %%
def add(x): 
    return x*2 
score=df['score'].map(add)
print("added the student score is:\n",score)
# Out:
# added the student score is:
#  0     60
# 1     80
# 2    100
# 3     40
# Name: score, dtype: int64

# %%
plt.scatter(df["study_our"],df["score"])
plt.title("scatter plot")
plt.xlabel("study_our")
plt.ylabel("score")    
plt.show()

# %% [markdown]
# # linear Regresion

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("C:/Users/Pramoda A S/Desktop/AIML Documents/DataSets in CSV files/StudentStudyHour1.csv")

# %%
df
# Out:
#     Hours  Scores
# 0     2.5    21.0
# 1     5.1    47.0
# 2     3.2    27.0
# 3     8.5    75.0
# 4     3.5    30.0
# 5     1.5    20.0
# 6     9.2    88.0
# 7     5.5    60.0
# 8     8.3     NaN
# 9     2.7    25.0
# 10    7.7    85.0
# 11    5.9    62.0
# 12    4.5    41.0
# 13    3.3    42.0
# 14    1.1    17.0
# 15    8.9    95.0
# 16    2.5     NaN
# 17    1.9    24.0
# 18    6.1    67.0
# 19    7.4    69.0
# 20    2.7    30.0
# 21    4.8    54.0
# 22    3.8    35.0
# 23    6.9    76.0
# 24    7.8    86.0
# 25    1.3    19.0
# 26    2.6    30.0
# 27    6.1    63.0

# %%
df.head(10)
# Out:
#    Hours  Scores
# 0    2.5    21.0
# 1    5.1    47.0
# 2    3.2    27.0
# 3    8.5    75.0
# 4    3.5    30.0
# 5    1.5    20.0
# 6    9.2    88.0
# 7    5.5    60.0
# 8    8.3     NaN
# 9    2.7    25.0

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    2
# dtype: int64

# %%
m=df["Scores"].mean() 
m
# Out:
# np.float64(49.53846153846154)

# %%
df["Scores"]=df["Scores"].fillna(m)

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# scores    0
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# scores    0
# dtype: int64

# %% [markdown]
# # split the data

# %%
x=df[["Hours"]]
y=df["Scores"]

# %%
x.head(10)
# Out:
#    Hours
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5
# 5    1.5
# 6    9.2
# 7    5.5
# 8    8.3
# 9    2.7

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
Lr=LinearRegression() 
Lr.fit(x_train,y_train) 
y_pred=Lr.predict(x_test)

# %%
print("the mse is:",mean_squared_error(y_test,y_pred))
# Out:
# the mse is: 26.709821216761473

# %%
print("rmse is:",r2_score(y_test,y_pred))
# Out:
# rmse is: 0.9244596147534438
